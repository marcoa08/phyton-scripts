# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoa08/ejercicios-fisica_computacional/blob/main/grafica_de_x%5E2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def f1(x):
  return -1.00*x**2+3*x #(-x^2+3x)

t1 = np.arange(-10.00, 15.00, 0.1)
plt.plot(t1, f1(t1))
plt.show()
